# %%
#Importing Libraries 
import yfinance as yf 
from datetime import date, timedelta 
import plotly.graph_objects as go
today = date.today()


#The current date (today) is converted into a string in the format YYYY-MM-DD and stored as d
d = today.strftime("%Y-%m-%d")
end_date = d 
d2 = date.today() -timedelta( days=840)
d2 =d2.strftime("%Y-%m-%d")
start_date = d2

# %%
#Using Yahoo Finance to get the data 
df = yf.download('PCBL.BO',start= start_date,
                         end = end_date,
                         progress=False)
df.head()
# Out:
#                   Open        High         Low       Close   Adj Close  Volume
# Date
# 2022-07-11  105.300003  116.500000  105.000000  114.900002  107.843552  236999
# 2022-07-12  117.000000  117.000000  113.550003  114.199997  107.186539   46530
# 2022-07-13  114.949997  118.150002  114.199997  115.250000  108.172050   72500
# 2022-07-14  114.000000  116.050003  108.800003  111.199997  104.370773   63668
# 2022-07-15  110.449997  115.449997  109.000000  109.599998  102.869034   83946

# %%
#Using Plotly.graph to get more precise graphs 
import plotly.graph_objects as go

#Candlestick charts depict the open, closing, high, and low prices of a security over a designated time.
figure = go.Figure(data=[go.Candlestick(
    x=df.index,
    open=df["Open"],
    high=df["High"],
    low=df["Low"],
    close=df["Close"]
)])
figure.update_layout(xaxis_rangeslider_visible = False)

figure.show()

# %%
import plotly.express as px

figure =px.line(df , x = df.index,
                 y ="Close")
figure.show()
